# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Exercise 1:

# %% [markdown]
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!')

# %% [markdown]
# Modified code:

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Explanation for number 1:
# The error is in Print the p **should be in small letter like this: p**, not in capital letter like this: P.

# %% [markdown]
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print'Hello world!')

# %% [markdown]
# Modified code:

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Explanation for number 2:
# the error was in this part:'Hello world!') wherein its missing its other parethesis.

# %% [markdown]
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!)

# %% [markdown]
# Modefied code:

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Explanation for number 3: the error was in this part: print('Hello world!) wherein its **missing its other single quotation**.

# %%
print('Hello world!'')

# %% [markdown]
# Modefied code:

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Explanation for number 4: the error was at this part: print('Hello world!'') wherein there is two or double quotation **it just should be just one or single quotation.**

# %% [markdown]
# #Exercise 2:

# %% [markdown]
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)

# %% [markdown]
# Explanation:

# %% [markdown]
# The output was 44, because we initialized 43 as x, then we add it to one which results to the answer 44 since 43+1 = 44.

# %% [markdown]
# # Exercise 3:

# %% [markdown]
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1
print(x)

# %% [markdown]
# Modified code:

# %%
x = 43
x = x + 1
print(x)

# %% [markdown]
# Explanation:

# %% [markdown]
# the error was at this part x = X + 1, wherein the variable called is wrong, it is X, but it should be in small letter x since it was initialized like it
